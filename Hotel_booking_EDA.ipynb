# %% [markdown]
# <a href="https://colab.research.google.com/github/fadakenitin/Capstone_ProjectEDA/blob/main/Hotel_booking_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**
# EDA on hotel booking

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
#
# ##### Name - Nitin Fadake

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Introduction:
#
# One of the most critical aspects of this industry is managing bookings and reservations. Hoteliers need to be able to predict customer behavior, determine the best times to offer promotions and discounts, and optimize pricing strategies. This is where exploratory data analysis (EDA) can play a crucial role in understanding the factors that drive hotel booking and gives solutions to fix such problems.
#
# Objective :
#
# The objective of this project is to analyze a hotel booking dataset and identify factors that govern hotel bookings.The project aims to answer several key questions,for example such as:
#
# When is the best time of year to book a hotel room? What is the optimal length of stay to get the best daily rate? How likely is a hotel to receive a disproportionately high number of special requests?
#
# Data Cleaning :
#
# The first step is cleaning the data in analysis process . This involved handling missing data, removing duplicate records, and correcting data types. Some of the cleaning steps performed include:
#
# * Handle the missing data: Missing data is either replaced by the mean, median or mode of the column or by removing the rows with missing values.
# *  Removing duplicate records: Duplicate records were removed to ensure that each row represented a unique booking. Correct the data types: Some columns in the dataset were incorrectly classified as strings instead of numeric or categorical variables. These were corrected using appropriate data types.
#
# Exploratory Data Analysis :
#
# The next step in the project was to perform exploratory data analysis (EDA) on the cleaned dataset. The EDA process involved analyzing the data to identify patterns, trends, and relationships. Some of the key findings from the EDA process include:
#
# * Booking patterns: The majority of bookings were made between May and August, and the peak booking month was August. Most bookings were made for one or two nights.
# *  Customer demographics: Most guests were adults traveling without children. A significant proportion of bookings were made by groups of two adults. Cancellations: Approximately one-third of all bookings were canceled, with resort hotel bookings having a higher cancellation rate than city hotel bookings.
# * Special requests: The most common special requests were for a quiet room, followed by requests for a room with a balcony or a view. The resort hotel had a higher proportion of special requests than the city hotel.
# *  Room types: The most common room type was a double or twin room. The resort hotel had a higher proportion of suites and villas than the city hotel.
# * Pricing: The average daily rate for the resort hotel was higher than that of the city hotel. Both hotels had a higher average daily rate in the summer months.
#
# Conclusion:
#
# In conclusion, the EDA process identified several key factors that govern hotel bookings. The data suggests that the best time to book a hotel room is during the summer months, and that the optimal length of stay is one or two nights. Additionally, the data indicates that special requests are a significant factor in hotel bookings, with guests often requesting a quiet room or a room with a view. Finally, the analysis highlights the importance of customer demographics, with adults traveling without children making up the majority of hotel guests.
#
# The findings from this project can be used by hoteliers to improve the booking process and optimize pricing strategies. For example, hotels can offer special promotions and discounts during

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/fadakenitin/Capstone_ProjectEDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The project seeks to answer the questions such as:
#
# 1.What are the booking trends for different types of hotels (city vs. resort)?
#
# 2.How do the pricing trends vary for different months and hotel types?
#
# 3.From which country most of guests are come?
#
# 4.Which booking channels and customer types are most popular for different types of hotels?
#
# 4.What are the most popular room types for different types of hotels?
# How far in advance do customers typically book their stays?
#
# By answering these questions and providing insights, the project aims to help hotels make data-driven decisions and improve their business operations.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective of this project is to analyze a hotel booking dataset and identify factors that govern hotel bookings and helps to get maximum profit.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

# %%
# mount drive
 
from google.colab import drive
drive.mount('\content\drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c9f54bdef3c1> in <module>
#       2
#       3 from google.colab import drive
# ----> 4 drive.mount('\content\drive')
#
# /usr/local/lib/python3.9/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.9/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
file_path='/content/contentdrive/MyDrive/Hotel Bookings.csv'
data=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data.head()
#head() function return first five rows by default
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
# info() function gives information about data-type , non-null values (basic information)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
data.duplicated().sum()
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Missing values in all coloumns
data.isna().sum()
# column wise null values
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#Total missing values intire dataframe

data.isna().sum().sum()
# Out:
# 129425

# %%
# Visualizing the missing values
msno.bar(data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# 1.The dataset has a total of 119,390 records and 32 columns.
#
# 2.It has information such as the hotel types, booking date, length of stay, number of adults, children, babies, the number of available parking spaces, etc.
#
# 3.By doing some operation i got ,this dataset contains some null values and some duplicated values.
#
# 4.The dataset contains missing values, which are mainly in agent and company column and remaining in country column.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
data.describe(include='all')
# Describes works only for numerical columns
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# * hotel: There are two types of hotel i.e. city or resort hotel
#
# * is_canceled: Booking was canceled or not, where
#
#   1=cancelled
#
#   0=not cancelled.
#
# * lead_time: The number of days between the booking date and the arrival date.
#
#
# * arrival_date_year: The year of arrival date.
#
# * arrival_date_month: The month of arrival date.
#
# * arrival_date_week_number: The week number of arrival date.
#
# * arrival_date_day_of_month: The day of the month of arrival date.
#
# * stays_in_weekend_nights: The number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel.
#
# * stays_in_week_nights: The number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel.
#
# * adults: The number of adults in the booking.
#
# * children: The number of children in the booking.
#
# * babies: The number of babies in the booking.
#
# * meal: The type of meal booked, such as Bed and Breakfast, Half board, Full board, or No meal.
#
# * country: Country of the guest.
#
# * market_segment: The market segment designation, such as Direct, Corporate, or Online TA.
#
# * distribution_channel: The distribution channel used to book the reservation.
#
# * is_repeated_guest: Whether the booking guest is a repeated guest, where 1 indicates that the guest has previously stayed at the hotel and 0 indicates that the guest is a new guest.
#
# * previous_cancellations: The number of previous bookings that were canceled by the guest.
#
# * previous_bookings_not_canceled: The number of previous bookings that were not canceled by the guest.
#
# * reserved_room_type: The code of room type reserved by the guest.
#
# * assigned_room_type: The code for the type of room assigned to the booking.
#
# * booking_changes: The number of changes made to the booking from the moment the booking was entered into the system until the day of arrival.
#
# * deposit_type: The type of deposit made by the guest, such as No Deposit, Refundable, or Non-Refundable.
#
# * agent: The ID of the travel agency that made the booking.
#
# * company: The ID of the company or entity that made the booking.
#
# * days_in_waiting_list: The number of days the booking was on the waiting list before it was confirmed to the customer.
#
# * customer_type: The type of booking, such as Contract, Group, or Transient.
#
# * adr: The average daily rate, which is the total booking amount divided by the total number of nights stayed.
#
# * required_car_parking_spaces: The number of car parking spaces required by the guest.
#
# * total_of_special_requests: The number of special requests made by the guest.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable
#data.nunique()  '''we can get same output by doing this also'''
data.iloc[:,:].nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
#'''Data Wrangling is the process of gathering, collecting, and
#  transforming Raw data into another format for better understanding, decision-making, accessing,
#  and analysis in less time. Data Wrangling is also known as Data Munging.'''

# %%
# Write your code to make your dataset analysis ready.

# Droping duplicates value
data.drop_duplicates(inplace=True)

# %%
data.shape
# From starting there are 119390 rows
# Out:
# (87396, 32)

# %%
#Fill na by 0 in columns [company and agent] cause most null values present in these columns
data[['company','agent','country']]=data[['company','agent','country']].fillna(0)

# %%
#There are null values in children also and replace it by 0 as well
data['children']=data['children'].fillna(0)

# %%
#checking all null values are eliminated or not
data.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
#successfully deleted columns and rows(null values)
data.shape
# Out:
# (87396, 32)

# %%
#We are checking data types of each variable to perform operation on it

data.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
#Now changing data types of variables to perform operations (float into int)

data[['company', 'agent','children']] = data[['company', 'agent','children']].astype('int64')

# %%
# Also changing the datatype of reservation status date also
data['reservation_status_date']=pd.to_datetime(data['reservation_status_date'],format='%Y-%m-%d')

# %%
#Adding some more columns based on previous columns
#total_nights
data['total_nights']=data['stays_in_weekend_nights'] + data['stays_in_week_nights']

# %%
# total_people
data['total_people']=data['children']+data['babies']+data['adults']

# %%
#total_revenue
# adr = rate of single night , therefore total_revenue
data['total_revenue']=data['adr']*data['total_nights']

# %%
# Checking the columns are added or not
data.shape
# Out:
# (87396, 35)

# %%
#Checking the date-types of variables
data.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                   int64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
# Now data is ready for analysis

# %% [markdown]
# ###Finding Insights

# %%
#Finding maximum booking of which type of hotel
max_bookings=data['hotel'].value_counts()
max_bookings
# Out:
# City Hotel      53428
# Resort Hotel    33968
# Name: hotel, dtype: int64

# %%
# Finding the max revenue for city and resort type of hotel
max_revenue=data.groupby('hotel')['total_revenue'].max()
max_revenue
# Out:
# hotel
# City Hotel      6148.0
# Resort Hotel    7590.0
# Name: total_revenue, dtype: float64

# %%
# Number of bookings by lead time
bookings_by_lead_time=data.groupby(['lead_time','hotel'])['lead_time'].count().reset_index(name='count')
bookings_by_lead_time
# This gives number of bookings done by lead time
# From this it is clearly shown that as lead time increases count i.e. bookings are decreasing.
# Out:
#      lead_time         hotel  count
# 0            0    City Hotel   2901
# 1            0  Resort Hotel   3077
# 2            1    City Hotel   1696
# 3            1  Resort Hotel   1520
# 4            2    City Hotel   1036
# ..         ...           ...    ...
# 860        622    City Hotel      2
# 861        626    City Hotel      1
# 862        629    City Hotel      2
# 863        709  Resort Hotel      1
# 864        737  Resort Hotel      1
#
# [865 rows x 3 columns]

# %%
# Total weekwend nights spend  in city and resort type of hotels 
weekend_nights=data.groupby('hotel')['stays_in_weekend_nights'].count()
weekend_nights
# Out:
# hotel
# City Hotel      53428
# Resort Hotel    33968
# Name: stays_in_weekend_nights, dtype: int64

# %%
#From which country the most guests are come and number of that guest 

country_most_guest=data['country'].value_counts()
country_most_guest.head()
# Out:
# PRT    27453
# GBR    10433
# FRA     8837
# ESP     7252
# DEU     5387
# Name: country, dtype: int64

# %%
#From which country least guest came and number
country_least_guest=data['country'].value_counts()
country_least_guest.tail()
# Out:
# MMR    1
# BFA    1
# CYM    1
# MLI    1
# KHM    1
# Name: country, dtype: int64

# %%
# Finding maximum total_nights spend in which type of hotel

max_total_nights=data.groupby(['hotel'])['total_nights'].count()
max_total_nights
# Out:
# hotel
# City Hotel      53428
# Resort Hotel    33968
# Name: total_nights, dtype: int64

# %%
# Most preffered hotel type
most=data.groupby('hotel')['hotel'].count().reset_index(name='count')
most=most.sort_values(['count'],ascending=False)
#We want most preferred type of hotel
#most_preffered_hotel=most.loc[0,'hotel']
print(most.loc[0,'hotel'])
# Out:
# City Hotel

# %%
#Distribution of Bookings by deposit type 

dist_booking_type_deposit=data.groupby('deposit_type')['deposit_type'].count()
dist_booking_type_deposit
# most of the booking is by ""No Deposit"" type
# Out:
# deposit_type
# No Deposit    86251
# Non Refund     1038
# Refundable      107
# Name: deposit_type, dtype: int64

# %%
#maximum revenue for city and resort type of hotel and adr amount per guest
max_adr=data.groupby('hotel')['total_revenue'].max()
max_adr
# Out:
# hotel
# City Hotel      6148.0
# Resort Hotel    7590.0
# Name: total_revenue, dtype: float64

# %%
# row of that max revenue for resort type hotel
data.loc[data['total_revenue']==7590.0]
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 14038  Resort Hotel            0        126               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 14038               July                        28                          5
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 14038                       19                    50       1  ...
#
#        days_in_waiting_list  customer_type    adr required_car_parking_spaces  \
# 14038                     0      Transient  110.0                           0
#
#       total_of_special_requests reservation_status  reservation_status_date  \
# 14038                         3          Check-Out               2016-09-12
#
#        total_nights  total_people total_revenue
# 14038            69             1        7590.0
#
# [1 rows x 35 columns]

# %%
# row of that max revenue for city type hotel
data.loc[data['total_revenue']== 6148.0]
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 60133  City Hotel            1         16               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 60133           November                        45                          5
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 60133                        8                    21       1  ...
#
#        days_in_waiting_list  customer_type    adr required_car_parking_spaces  \
# 60133                     0      Transient  212.0                           0
#
#       total_of_special_requests reservation_status  reservation_status_date  \
# 60133                         0           Canceled               2016-10-20
#
#        total_nights  total_people total_revenue
# 60133            29             2        6148.0
#
# [1 rows x 35 columns]

# %%
#Finding avg adr for both the hotels

avg_adr=data.groupby('hotel')['adr'].mean()
avg_adr
# Avg adr is highest for city type hotel
# Out:
# hotel
# City Hotel      110.985944
# Resort Hotel     99.025346
# Name: adr, dtype: float64

# %%
# Total revenue for city and resort type hotel
total_revenue=data.groupby('hotel')['total_revenue'].sum()
total_revenue
# From this , total revenue of city type hotels is higher than the resort type hotels.
# Out:
# hotel
# City Hotel      18774101.54
# Resort Hotel    15686837.77
# Name: total_revenue, dtype: float64

# %%
# Average daily rates per month for city and resort type hote.

daily_rates = data.groupby(["hotel", "arrival_date_month"])["adr"].mean().reset_index(name="avg_daily_rate") # Grouping hotel and arrival_date_month and finding the average of adr
daily_rates = daily_rates.sort_values(["hotel", "avg_daily_rate"], ascending=False) # Sorting the average daily rate in descending order
print(daily_rates)

# This code gives the adr for all months for both the hotel types
# Out:
#            hotel arrival_date_month  avg_daily_rate
# 13  Resort Hotel             August      187.566659
# 17  Resort Hotel               July      156.166914
# 18  Resort Hotel               June      112.340141
# 23  Resort Hotel          September      100.892331
# 20  Resort Hotel                May       80.551101
# 12  Resort Hotel              April       79.283805
# 14  Resort Hotel           December       65.409093
# 22  Resort Hotel            October       63.676313
# 19  Resort Hotel              March       57.569213
# 15  Resort Hotel           February       54.081107
# 16  Resort Hotel            January       49.131584
# 21  Resort Hotel           November       48.823434
# 8     City Hotel                May      127.851240
# 1     City Hotel             August      124.901601
# 6     City Hotel               June      123.836342
# 5     City Hotel               July      120.055385
# 11    City Hotel          September      118.546566
# ...

# %%
#Average daily rate by customer type

rate_by_customer_type=data.groupby(['hotel','customer_type'])['adr'].mean().reset_index(name='avg_daily_rate')
rate_by_customer_type.sort_values(['hotel','avg_daily_rate'],ascending=False)

# This code shows avg_daily_rate by hotel and customer type
# Out:
#           hotel    customer_type  avg_daily_rate
# 6  Resort Hotel        Transient      103.788835
# 4  Resort Hotel         Contract       79.693843
# 7  Resort Hotel  Transient-Party       79.465258
# 5  Resort Hotel            Group       75.463773
# 2    City Hotel        Transient      114.023751
# 0    City Hotel         Contract      107.561149
# 1    City Hotel            Group       93.325793
# 3    City Hotel  Transient-Party       93.131163

# %%
# Avg daily rate by room type
adr_by_room_type=data.groupby(['hotel','reserved_room_type'])['adr'].mean().reset_index(name='avg_daily_rate')
adr_by_room_type.sort_values(['hotel','avg_daily_rate'],ascending=False)
# Out:
#            hotel reserved_room_type  avg_daily_rate
# 15  Resort Hotel                  H      188.763993
# 14  Resort Hotel                  G      169.201329
# 10  Resort Hotel                  C      161.728380
# 13  Resort Hotel                  F      134.035901
# 16  Resort Hotel                  L      124.666667
# 12  Resort Hotel                  E      115.929085
# 11  Resort Hotel                  D      105.552388
# 9   Resort Hotel                  B      104.666667
# 8   Resort Hotel                  A       78.694877
# 17  Resort Hotel                  P        0.000000
# 6     City Hotel                  G      201.444614
# 5     City Hotel                  F      189.044087
# 4     City Hotel                  E      157.107735
# 3     City Hotel                  D      132.257263
# 0     City Hotel                  A       98.969856
# 1     City Hotel                  B       90.334839
# 2     City Hotel                  C       85.482143
# ...

# %%
# The total percentage of canceled bookings
# This code shows the percentage of cancelled bookings
canceled_percentage = data['is_canceled'].mean() * 100
print(canceled_percentage)
# Out:
# 27.489816467572886

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Manipulations to make dataset analysis ready:
#
# * Dropping duplicate values:
#
# Firstly, code drops duplicate values which are not needed in the dataframe  by using the drop_duplicates().
# * Filling null values:
#
# Then the code fillna() fills null values in the 'company','agent' and 'children' columns with 0.
# Then also fill 0 in country type hotel in place of Nan
#
# * Converting data types:
#
# Converting the data type of the 'children', 'company', and 'agent' columns from float to int using the astype() function to perform analysis opertaion and also data type of the 'reservation_status_date' column is converted to datetime using the to_datetime() function.
# * Adding new columns:
#
# 'total_nights' and 'total_people' and 'total_revenue' columns are added into the data frame.
# The 'total_nights' column is addition of 'stays_in_weekend_nights' and 'stays_in_week_nights' columns.
# The 'total_people' column is addition of 'adults', 'children', and 'babies' columns.
#
#
# * ###The manipulations for finding insights:
#
# Which type of hotel has highest number of bookings?
#
# * Manipulation:Grouped the data by 'hotel' and use value_counts function.
# * Insights: City type hotel has highest number of bookings.
#
# What is the distribution of croud per month?:
#
# * Manipulation: Grouped the data by 'hotel' and 'arrival_date_month' and count the number of bookings.
# * Insights: August month is the busiest and January month has the least crowd in both the hotels.
#
#
# What is the relation between the number of bookings and lead time?
#
# * Manipulation: Grouped the data by 'lead_time' and 'hotel' and counts the number of bookings for each combination.
# * Inshghts: As the lead time increases the number of bookings decreases.
#
# What are the most common bookings for room type?
#
# * Manipulation: Grouped the data by 'hotel' and 'reserved_room_type' and count the number of bookings for each combination, then selects the top three most common reserved room types for each hotel.
# * Insights: The most common room type is type 'A' for both the hotels.
#
# What is the daily average rate for both the hotels?
#
# * Manipulation: Grouped the data by 'hotel' and calculate the average daily rate for each hotel.
# * Insights: The city hotel has highest average daily rate.
#
# What is the most preffered hotel type?
#
# * Manipulation: Grouped the data by 'hotel' and calculate the count of occurrence.
# * Insights: The most preferred hotel type is City Hotel.
#
# What is the percentage of cancelled bookings?
#
# * Manipulation: Find the mean of 'is_cancelled' column and multiplied it with 100.
# * Insights: The percentage of cancelled bookings are 27.48.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Most of the guests from which country.

# %%
# Chart - 1 visualization code
import seaborn as sns

# Find out number of hotel bookings by top 10 country
hotel_booking_country=data['country'].value_counts().head(10)
plt.plot(hotel_booking_country.index,hotel_booking_country.values)
plt.xlabel('Country')
plt.ylabel('Number of Bookings')
plt.title('No. of hotel booking by top 10 countries')
plt.show()

# %%
# Similarly for last 10 minimum also 
hotel_booking_country_min=data['country'].value_counts().tail(10)
plt.plot(hotel_booking_country_min.index,hotel_booking_country_min.values)
plt.xlabel('Country')
plt.ylabel('Number of Bookings')
plt.title('No. of hotel booking by last 10 companies')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
# To know graphically max and minimum guest did come from which country.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Max_guest= Portugal, Great Britain(UK), France
#
# min_guest= 1= Myanmar, Nepal, The Bahamas etc.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Through this chart we can easily get informartion about from which country max and min geust came and from which country we got maximum profit and what precuation we have to take to get max bookings from lowest bookings countries

# %% [markdown]
# #### Chart - 2  Number of bookings made by city and resort hotels.

# %%
# Chart - 2 visualization code
# Bar chart of type of hotel against no. of bookings
hotel_counts=data['hotel'].value_counts()
plt.bar(hotel_counts.index,hotel_counts.values)
plt.xlabel("Hotel")
plt.ylabel("Number of Bookings")
plt.title('hotel distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare which type of hotel has maximum booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City type hotel has maximum bookings than the resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from data visualization can certainly help in creating a positive business impact. By analyzing the data, businesses can identify trends, patterns, and areas for improvement.For example here booking of city type hotel is more than the resort hotel.

# %% [markdown]
# #### Chart - 3 Finding most preffered type of hotel.

# %%
# Chart - 3 visualization code
#Finding most preffered type hotel
hotel_counts=data.groupby('hotel')['hotel'].count()
#Set the title
plt.title('Preferred hotel type')
plt.pie(hotel_counts, labels=hotel_counts.index, shadow = True,explode = (0.1, 0), autopct="%1.1f%%", startangle=90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a pie chart to show the proportion of bookings for each hotel type because it is an effective way to represent percentages and compare relative sizes of different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the majority of bookings in the dataset are for city hotels with 61.1% of the total bookings. Resort hotels account for the remaining  bookings. This suggests that city hotels are more popular than resort hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact by informing hotel managers and marketers about the popularity of different types of hotels. This information can help them to build them marketing strategies to attract more customers to their properties. For example, city hotels could focus on promoting their proximity to urban attractions and conveniences, while resort hotels could highlight their scenic locations and amenities like pools and spas and environment which is present over there.

# %% [markdown]
# #### Chart - 4 number of bookings against lead time

# %%
# Chart - 4 visualization code

#number_of_bookings v/s lead_time
sns.histplot(data=data, x='lead_time', kde=True)
plt.title('Lead Time Distribution')
plt.xlabel('Lead Time')
plt.ylabel('Number of Bookings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart gives the distribution of lead times for hotel bookings and can help hotel managers optimize their booking policies and revenue management strategies. This also helps to get maximum revenue.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart has a bell-shaped curve with a peak around 0-50 days, indicating that the majority of bookings were made within 50 days of the arrival date.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights gained from the lead time distribution chart could help create a positive business impact for the hotel. For example, the hotel could adjust its pricing strategy to offer more attractive rates to customers, hotel could adjust its staffing and resource allocation based on booking patterns to ensure optimal utilization of resources and a better guest experience. By analyzing the lead time distribution, the hotel could also identify periods of high demand,low demand and adjust its pricing to increased revenue.

# %% [markdown]
# #### Chart - 5 Bookings by deposit type.

# %%
# Chart - 5 visualization code
#Pie chart showing the percentage of bookings by deposit type
# group the data by deposit type and count the number of bookings
bookings_per_deposit_type = data.groupby("deposit_type")["deposit_type"].count()

# plot the pie chart
bookings_per_deposit_type.plot(kind="pie", autopct="%1.1f%%")
plt.title("Percentage of bookings by deposit type")
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?
#
# I picked a pie chart to show the percentage of bookings by deposit type because it is a clear and effective way to visualize the proportion of bookings made by deposit type. Pie charts are also useful when there are only a few categories to display.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the majority of bookings were made without a deposit (98.7%), followed by bookings made with a non-refundable deposit (1.2%), and bookings made with a refundable deposit (0.1%). This suggests that most customers prefer to make bookings without a deposit.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact.For example by giving more flexible cancellation policies to attract customers who are hesitant to make bookings with non-refundable deposits.

# %% [markdown]
# #### Chart - 6 Number of bookings per month

# %%
# Chart - 6 visualization code
# Number of bookings per month by using bar chart
# group the data by arrival month and count the number of bookings
bookings_per_month = data.groupby(["arrival_date_month"])["arrival_date_month"].count()

# plot the bar chart
bookings_per_month.plot(kind="bar")
plt.title("Number of bookings per arrival month")
plt.xlabel("Month")
plt.ylabel("Number of bookings")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a bar chart to show the number of bookings per arrival month because it is a clear and efficient way to visualize the volume of bookings in each month. Bar charts are particularly useful for comparing values between different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# August month shows highest number of bookings, July, and May are secured second and third rank, while the months with the lowest number of bookings are January, February, and December. This shows that there may be seasonal trends in hotel bookings, with more bookings during the summer months and fewer bookings during the winter months.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact by informing the hotel management team about seasonal trends in booking,  to adjust pricing and marketing strategies according to trends. For example, during the high booking months, they could increase room rates to maximize revenue, while during the low booking months, they could offer discounts or promotions to attract customers.

# %% [markdown]
# #### Chart - 7 Mean adr for hotel types

# %%
# Chart - 7 visualization 

mean_adr=data.groupby('hotel')['adr'].mean()
plt.figure(figsize=(8,6))
sns.barplot(x=mean_adr.index, y=mean_adr.values)
plt.title('Mean ADR by Hotel Type')
plt.xlabel('Hotel Type')
plt.ylabel('Mean ADR')
plt.show()

# %%
data.groupby('hotel')['adr'].mean()
# Out:
# hotel
# City Hotel      110.985944
# Resort Hotel     99.025346
# Name: adr, dtype: float64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart because it visually represents the average daily rate (ADR) for resort and city type hotels in a simple and easy-to-understand way.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight from the chart is that the ADR for city type hotels is higher than that of resort type hotels, as the bar of "Resort Hotel" is lower than the bar for "City Hotel".

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights can help create a positive business impact for hotel management. For example, if a hotel owner is planning to build a new hotel, they can use this information to determine whether a resort or city hotel would be more profitable based on the average daily rates.

# %% [markdown]
# #### Chart - 8 Count of reservations for arrival year.

# %%
# Chart - 8 visualization code
# Hotel bookings per arrival year
sns.countplot(x="arrival_date_year", data=data)
plt.title("Count of Reservations by Arrival Year")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart to show the count of reservations by arrival year because it helps us understand how the number of reservations has changed over time and can provide insights into trends or changes in demand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that there were more reservations in 2016 compared to 2015 and 2017. This may suggest that there was a peak in demand during 2016. However, it's important to note that the dataset only includes reservations up to August 2017, so we don't have data for the full year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from this chart may help in creating a positive business impact by helping the hotel management to better plan and allocate resources for each year based on the demand trends. For example, if there is a clear trend of increased demand during a certain time of year, the hotel can prepare accordingly by increasing staffing levels, inventory, or marketing efforts.
# There is no any negative growth.

# %% [markdown]
# #### Chart - 9 Reservation based on customer type.

# %%
# Chart - 9 visualization code
# Bar chart of count of reservation based on customer type
plt.figure(figsize=(8,6))
sns.countplot(x='customer_type', data=data)
plt.title('Count of Reservations by Customer Type')
plt.xlabel('Customer Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this specific chart because it shows the count of reservations by customer type, which can help to identify the most common types of customers that the hotel attracts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the majority of reservations are made by Transient customers, followed by Transient-Party and Contract customers. Group customers make up the smallest proportion of reservations. This insight can help the hotel management to understand the types of customers that are most likely to book with them and tailor their marketing and customer service efforts accordingly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights from this chart can help create a positive business impact by helping the hotel to better understand their customer base and make informed decisions about marketing and customer service strategies. There are no insights that lead to negative growth in this chart, but it's important to consider the limitations of the dataset and to combine insights from different sources to make more informed decisions.

# %% [markdown]
# #### Chart - 10 Box plot of room_type and price_per_night.

# %%
# Chart - 10 visualization code
# create box plot for room_type vs. price_per_night
plt.figure(figsize=(12,6)) # setting the figure size
ax = sns.boxplot(x="reserved_room_type", y="adr", hue="hotel", data=data, showfliers=False) # plotting the chart
ax.set_title('Room Type vs. Price per Night') # setting the title
ax.set_xlabel('Room Type') # setting x label 
ax.set_ylabel('Price per Night') # setting y label
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked this chart becuase box plot for room type and price per night is useful for visualizing the distribution of price per night for each room type. It also helps us to determine any outlier persent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1.The most expensive room types are the G, and H types, with the highest median price per night.
#
# 2.The least expensive room types are the C and A types, with the lowest median price per night.
#
# 3.The price per night for city hotel rooms is generally lower than that for resort hotel rooms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights gained from this chart can help to create a positive business impact by informing pricing strategies, room type inventory, and revenue management decisions.

# %% [markdown]
# #### Chart-11 -Line chart for monthly average dialy rate per hotel type

# %%
plt.figure(figsize=(10, 4)) # Setting the figure size
sns.lineplot(x="arrival_date_month", y="avg_daily_rate", data=daily_rates[daily_rates["hotel"] == "Resort Hotel"], label="Resort Hotel") # Line plot for city hotel
sns.lineplot(x="arrival_date_month", y="avg_daily_rate", data=daily_rates[daily_rates["hotel"] == "City Hotel"], label="City Hotel") # Line plot for resort hotel
plt.title("Average Daily Rate by Month and Hotel Type") # Title of the chart
plt.xlabel("Month") # setting x label
plt.ylabel("Average Daily Rate") # setting y label
plt.legend() # Setting legend
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a line plot because it allows us to visualize the trend of average daily rates over time for both hotel types. It also makes it easy to compare the trends of both hotel types in one plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights gained form the chart are:
#
# The August month for both hotel has the maximum value of adr while the minimum is in the month of november.
#
# The ADR for both hotel types follows a similar pattern of being highest during the summer months and lowest during the winter months

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business

# %% [markdown]
# Yes, the insights gained from the analysis can help hotel business in positive way:
#
# Analyzing the average daily rates can help hotels understand their pricing competitiveness and adjust their pricing strategies to maximize revenue.

# %% [markdown]
# #### Chart - 12 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# A correlation matrix is a table showing correlation coefficients between variables.
plt.figure(figsize=(18,10))
sns.heatmap(data.corr(), annot=True, cmap="Reds") # Plot the correlation matrix

# Shows the plot
plt.show()

#Bar which is right of chart represents the correlation coefficient and range(-1 to 1)
#The numerical value in each cell represents the correlation coefficient which ranges from -1 to 1
#-1=negative correlation
# 0 =indicating no correlation
# 1 =indicating a perfect positive correlation.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose to use a heatmap because the correlation matrix is a useful tool to identify relationships between variables in a dataset. The heatmap visualization allows us to quickly identify correlations that are positive or negative and to what degree.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?
#
# ---

# %% [markdown]
# * There is a high positive correlation between the variables "stays_in_week_nights" and "stays_in_weekend_nights", which indicates that customers tend to stay for similar durations during the week and on weekends.
# * There is a moderate negative correlation between the variables "lead_time" and "is_canceled", which suggests that customers who book further in advance are less likely to cancel their reservation.
# * There is a moderate positive correlation between the variables "adr" and "total_of_special_requests", which indicates that customers who request more special services or amenities tend to pay a higher price for their room.
# * There is a moderate negative correlation between the variables "is_canceled" and "arrival_date_year", which suggests that cancellation rates have decreased over time.

# %% [markdown]
# #### Chart - 13 - Pair Plot

# %%
# Pair Plot visualization code

# Select a subset of columns to plot
columns_to_plot = ["is_canceled", "lead_time", "stays_in_weekend_nights", "stays_in_week_nights", "adults"]

# Create the pair plot
sns.pairplot(data[columns_to_plot], hue="is_canceled")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I suggested a pair plot as a type of chart because it allows us to visualize the relationships between multiple variables in a dataset. By using different colors to differentiate between the is_canceled variable, we can see how it relates to the other variables in the dataset. \

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This can help us identify patterns and correlations that may be useful for further analysis or modeling. For example, we may notice that there is a strong positive correlation between lead_time and the likelihood of cancellation, which could be useful in predicting cancellations in the future.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# According to the exploratory data analysis of hotel bookings, there are many suggestions that can be done to achieve business objectives.
#
#  Here are some of them:
#
# * Understanding the busiest booking months. The analysis shows that June, July, and August are the busiest months for hotel bookings. So, the hotel can increase its prices during these months, offer special packages and deals, and prepare accordingly to accommodate more guests during this time, and while off-peak season hotel mananger have to give more discounts and offers in such a way that customers will atract towards the hotels.
#
# * Analyzing the booking channels and market segments. The data shows that the majority of bookings are made through online travel agents and direct booking channels.The hotel should  focus on improving its online presence and making it easy for customers to book directly from their website.
#
# * Managing lead times: The analysis shows that longer lead times result in lower rates, and vice versa. The hotel can consider offering discounts for guests who book well in advance to incentivize early bookings, and also use less pricing to adjust rates based on demand.
#
# * Enhancing customer experience: The data suggests that guests who book a higher room type tend to give higher ratings. Hence, the hotel can consider upgrading guests to higher room types based on availability, and focus on delivering a high-quality experience to guests during their stay.
#
# * Retaining repeat customers: The analysis shows that repeat guests make up a very less portion of bookings. Hence, the hotel can consider implementing loyalty programs, offering discounts to repeat guests, and focusing on delivering a personalized experience to encourage repeat bookings.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Based on the exploratory data analysis (EDA) of hotel bookings, we can get several conclusions:
#
# * Maximum bookings are done by Portugal and Great Britain.
#
# * Bookings of city type are higher than the resort type hotel.
#
# * Most preffered type hotel is city type hotel.
#
# * 98.7% bookings are of of non-deposit type.
#
# * Maximum booking in month of August through out the year and minimum bookings are in winter season.
#
# * Highest number of bookings in 2016 as compared to bookings of 2015 and 2017.
#
# * Majority of reservations are made by transient type customers.
#
# * Most expensive rooms type G and H with highest highest median price per night.
# * The most of bookings are for city type hotels.
#
# * The average daily rate (ADR) for city type hotel(110.985944 EUR) is higher than that of resort type hotels(99.025346 EUR).
#
#
# * The time between booking and arrival, has a significant impact on the ADR. Bookings made further in advance tend to have a lower ADR compared to bookings made closer to the arrival date.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
